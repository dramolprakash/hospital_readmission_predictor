# %% [markdown]
# ### Block 1: Environment Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)

print("Environment setup complete!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# Environment setup complete!
# Pandas version: 3.0.3
# NumPy version: 2.4.6

# %% [markdown]
# ### Block 2: Configuration — Samples & File Paths

# %%
import os

RAW = "data/raw/"
PROCESSED = "data/processed/"
SAMPLES = [1, 2, 3, 4, 5]

os.makedirs(PROCESSED, exist_ok=True)

def raw_path(pattern, sample, part=""):
    return os.path.join(RAW, pattern.format(N=sample, P=part))

# Verify files exist for each sample
data_types = {
    "Beneficiary 2008": "DE1_0_2008_Beneficiary_Summary_File_Sample_{N}.csv",
    "Beneficiary 2009": "DE1_0_2009_Beneficiary_Summary_File_Sample_{N}.csv",
    "Beneficiary 2010": "DE1_0_2010_Beneficiary_Summary_File_Sample_{N}.csv",
    "Inpatient":        "DE1_0_2008_to_2010_Inpatient_Claims_Sample_{N}.csv",
    "Outpatient":       "DE1_0_2008_to_2010_Outpatient_Claims_Sample_{N}.csv",
    "Carrier A":        "DE1_0_2008_to_2010_Carrier_Claims_Sample_{N}A.csv",
    "Carrier B":        "DE1_0_2008_to_2010_Carrier_Claims_Sample_{N}B.csv",
    "PDE":              "DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_{N}.csv",
}

print("FILE AVAILABILITY CHECK")
print("=" * 50)
all_ok = True
for label, pattern in data_types.items():
    for n in SAMPLES:
        path = raw_path(pattern, n)
        if not os.path.exists(path):
            print(f"  MISSING: {label} Sample {n}")
            all_ok = False

if all_ok:
    print(f"All {len(data_types) * len(SAMPLES)} files present for samples {SAMPLES}")
else:
    print("Some files missing — check above")
# Out:
# FILE AVAILABILITY CHECK
# ...
# All 40 files present for samples [1, 2, 3, 4, 5]

# %% [markdown]
# ### Block 3: Data Type Optimisation Functions

# %%
def optimize_beneficiary(df):
    """Fix chronic condition encoding and reduce memory for beneficiary files."""
    df = df.copy()
    chronic_cols = [c for c in df.columns if c.startswith('SP_') and c != 'SP_STATE_CODE']
    for col in chronic_cols:
        df[col] = (df[col] == 1)

    if 'BENE_ESRD_IND' in df.columns:
        df['BENE_ESRD_IND'] = df['BENE_ESRD_IND'].astype(str).str.upper().eq('Y')

    for col in ['BENE_SEX_IDENT_CD', 'BENE_RACE_CD', 'SP_STATE_CODE']:
        if col in df.columns:
            df[col] = df[col].astype('category')
    return df


def optimize_inpatient(df):
    """Standardise inpatient data types."""
    df = df.copy()
    for col in ['PRVDR_NUM', 'CLM_DRG_CD']:
        if col in df.columns:
            df[col] = df[col].astype('category')
    diag_cols = [c for c in df.columns if c.startswith('ICD9_DGNS_CD_')]
    for col in diag_cols:
        df[col] = df[col].astype(str).replace('nan', pd.NA)
    return df


def optimize_outpatient(df):
    """Keep key columns and standardise outpatient data."""
    keep = ['DESYNPUF_ID', 'CLM_ID', 'CLM_FROM_DT', 'CLM_THRU_DT',
            'PRVDR_NUM', 'AT_PHYSN_NPI', 'OP_PHYSN_NPI', 'CLM_PMT_AMT',
            'NCH_BENE_PTB_DDCTBL_AMT', 'NCH_BENE_PTB_COINSRNC_AMT',
            'ICD9_DGNS_CD_1', 'ADMTNG_ICD9_DGNS_CD', 'HCPCS_CD_1']
    keep = [c for c in keep if c in df.columns]
    df = df[keep].copy()
    if 'PRVDR_NUM' in df.columns:
        df['PRVDR_NUM'] = df['PRVDR_NUM'].astype('category')
    return df


def optimize_carrier(df):
    """Keep key columns and standardise carrier/physician data."""
    keep = ['DESYNPUF_ID', 'CLM_ID', 'CLM_FROM_DT', 'CLM_THRU_DT',
            'PRF_PHYSN_NPI_1', 'ICD9_DGNS_CD_1', 'HCPCS_CD_1',
            'LINE_NCH_PMT_AMT_1', 'LINE_ALOWD_CHRG_AMT_1']
    keep = [c for c in keep if c in df.columns]
    return df[keep].copy()


def optimize_pde(df):
    """PDE is already compact — just ensure correct types."""
    df = df.copy()
    if 'PROD_SRVC_ID' in df.columns:
        df['PROD_SRVC_ID'] = df['PROD_SRVC_ID'].astype(str)
    return df


print("Optimisation functions defined")
# Out:
# Optimisation functions defined

# %% [markdown]
# ### Block 4: Load Beneficiary Summary Files (Samples 1–5, All Years)

# %%
def load_beneficiary_year(year, samples):
    pattern = f"DE1_0_{year}_Beneficiary_Summary_File_Sample_{{N}}.csv"
    frames = []
    for n in samples:
        path = raw_path(pattern, n)
        df = pd.read_csv(path)
        df['SOURCE_SAMPLE'] = n
        frames.append(df)
        print(f"  Sample {n}: {len(df):,} rows")
    combined = pd.concat(frames, ignore_index=True)
    return optimize_beneficiary(combined)

print("Loading Beneficiary 2008...")
df_ben_2008 = load_beneficiary_year(2008, SAMPLES)
print(f"  Total: {len(df_ben_2008):,} rows | {df_ben_2008.memory_usage(deep=True).sum()/1024**2:.1f} MB\n")

print("Loading Beneficiary 2009...")
df_ben_2009 = load_beneficiary_year(2009, SAMPLES)
print(f"  Total: {len(df_ben_2009):,} rows | {df_ben_2009.memory_usage(deep=True).sum()/1024**2:.1f} MB\n")

print("Loading Beneficiary 2010...")
df_ben_2010 = load_beneficiary_year(2010, SAMPLES)
print(f"  Total: {len(df_ben_2010):,} rows | {df_ben_2010.memory_usage(deep=True).sum()/1024**2:.1f} MB")
# Out:
# Loading Beneficiary 2008...
#   Sample 1: 10,000 rows
#   Sample 2: 10,000 rows
#   Sample 3: 10,000 rows
#   Sample 4: 10,000 rows
#   Sample 5: 10,000 rows
#   Total: 50,000 rows | 8.3 MB
#
# Loading Beneficiary 2009...
#   Sample 1: 9,856 rows
#   Sample 2: 9,842 rows
#   Sample 3: 9,863 rows
#   Sample 4: 9,857 rows
#   Sample 5: 9,849 rows
#   Total: 49,267 rows | 8.2 MB
#
# Loading Beneficiary 2010...
#   Sample 1: 9,710 rows
#   Sample 2: 9,701 rows
#   Sample 3: 9,697 rows
#   Sample 4: 9,700 rows
#   Sample 5: 9,703 rows
#   Total: 48,511 rows | 8.1 MB

# %% [markdown]
# ### Block 4b: Beneficiary Exploration

# %%
print("BENEFICIARY SUMMARY")
print("=" * 40)
print(f"2008: {len(df_ben_2008):,} | Unique IDs: {df_ben_2008['DESYNPUF_ID'].nunique():,}")
print(f"2009: {len(df_ben_2009):,} | Unique IDs: {df_ben_2009['DESYNPUF_ID'].nunique():,}")
print(f"2010: {len(df_ben_2010):,} | Unique IDs: {df_ben_2010['DESYNPUF_ID'].nunique():,}")

chronic_cols = [c for c in df_ben_2008.columns if c.startswith('SP_') and c != 'SP_STATE_CODE']
print(f"\nCHRONIC CONDITIONS (2008 prevalence, top 5):")
prev = df_ben_2008[chronic_cols].mean().sort_values(ascending=False).head(5)
for col, rate in prev.items():
    print(f"  {col}: {rate*100:.1f}%")

print(f"\nMissing values in 2008 beneficiary:")
miss = df_ben_2008.isnull().sum()
print(miss[miss > 0].to_string() if miss.any() else "  None")
# Out:
# BENEFICIARY SUMMARY
# ...
# 2008: 50,000 | Unique IDs: 50,000
# 2009: 49,267 | Unique IDs: 49,267
# 2010: 48,511 | Unique IDs: 48,511
#
# CHRONIC CONDITIONS (2008 prevalence, top 5):
#   SP_ISCHMCHT: 41.8%
#   SP_DIABETES: 37.9%
#   SP_CHF: 28.5%
#   SP_DEPRESSN: 21.4%
#   SP_ALZHDMTA: 19.2%
#
# Missing values in 2008 beneficiary:
# BENE_DEATH_DT    49267

# %% [markdown]
# ### Block 5: Load Inpatient Claims (Samples 1–5)

# %%
def load_claims(pattern, samples, optimize_fn, label):
    frames = []
    for n in samples:
        path = raw_path(pattern, n)
        df = pd.read_csv(path)
        df['SOURCE_SAMPLE'] = n
        frames.append(df)
        print(f"  Sample {n}: {len(df):,} rows")
    combined = pd.concat(frames, ignore_index=True)
    return optimize_fn(combined)

print("Loading Inpatient Claims...")
df_inpatient = load_claims(
    "DE1_0_2008_to_2010_Inpatient_Claims_Sample_{N}.csv",
    SAMPLES, optimize_inpatient, "Inpatient"
)
print(f"  Total: {len(df_inpatient):,} rows | {df_inpatient.memory_usage(deep=True).sum()/1024**2:.1f} MB")
print(f"  Unique beneficiaries: {df_inpatient['DESYNPUF_ID'].nunique():,}")

# Year distribution
if 'CLM_THRU_DT' in df_inpatient.columns:
    df_inpatient['DISCHARGE_YEAR'] = df_inpatient['CLM_THRU_DT'] // 10000
    print(f"\nClaims by year:")
    print(df_inpatient['DISCHARGE_YEAR'].value_counts().sort_index().to_string())
# Out:
# Loading Inpatient Claims...
#   Sample 1: 5,775 rows
#   Sample 2: 5,888 rows
#   Sample 3: 5,615 rows
#   Sample 4: 5,672 rows
#   Sample 5: 5,745 rows
#   Total: 28,695 rows | 19.4 MB
#   Unique beneficiaries: 16,181
#
# Claims by year:
# DISCHARGE_YEAR
# 2008.0    11757
# 2009.0    10893
# 2010.0     6018

# %% [markdown]
# ### Block 6: Load Outpatient Claims (Samples 1–5) — NEW

# %%
print("Loading Outpatient Claims...")
df_outpatient = load_claims(
    "DE1_0_2008_to_2010_Outpatient_Claims_Sample_{N}.csv",
    SAMPLES, optimize_outpatient, "Outpatient"
)
print(f"  Total: {len(df_outpatient):,} rows | {df_outpatient.memory_usage(deep=True).sum()/1024**2:.1f} MB")
print(f"  Unique beneficiaries: {df_outpatient['DESYNPUF_ID'].nunique():,}")
print(f"  Columns retained: {list(df_outpatient.columns)}")

if 'CLM_FROM_DT' in df_outpatient.columns:
    df_outpatient['OP_YEAR'] = df_outpatient['CLM_FROM_DT'] // 10000
    print(f"\nOutpatient claims by year:")
    print(df_outpatient['OP_YEAR'].value_counts().sort_index().to_string())
    df_outpatient.drop(columns=['OP_YEAR'], inplace=True)

print(f"\nMissing values:")
miss = df_outpatient.isnull().sum()
print(miss[miss > 0].to_string() if miss.any() else "  None")
# Out:
# Loading Outpatient Claims...
#   Sample 1: 67,834 rows
#   Sample 2: 67,765 rows
#   Sample 3: 69,287 rows
#   Sample 4: 67,404 rows
#   Sample 5: 67,824 rows
#   Total: 340,114 rows | 40.3 MB
#   Unique beneficiaries: 36,626
#   Columns retained: ['DESYNPUF_ID', 'CLM_ID', 'CLM_FROM_DT', 'CLM_THRU_DT', 'PRVDR_NUM', 'AT_PHYSN_NPI', 'OP_PHYSN_NPI', 'CLM_PMT_AMT', 'NCH_BENE_PTB_DDCTBL_AMT', 'NCH_BENE_PTB_COINSRNC_AMT', 'ICD9_DGNS_CD_1', 'ADMTNG_ICD9_DGNS_CD', 'HCPCS_CD_1']
#
# Outpatient claims by year:
# OP_YEAR
# 2007.0       151
# 2008.0    121670
# 2009.0    138886
# 2010.0     74494
#
# Missing values:
# CLM_FROM_DT              4913
# CLM_THRU_DT              4913
# AT_PHYSN_NPI             7685
# OP_PHYSN_NPI           282407
# ICD9_DGNS_CD_1           2469
# ADMTNG_ICD9_DGNS_CD    256913
# HCPCS_CD_1              61966

# %% [markdown]
# ### Block 7: Load Carrier Claims (Samples 1–5, A+B) — NEW

# %%
print("Loading Carrier Claims (A+B parts per sample)...")
carrier_frames = []
for n in SAMPLES:
    for part in ['A', 'B']:
        path = raw_path("DE1_0_2008_to_2010_Carrier_Claims_Sample_{N}{P}.csv", n, part)
        df = pd.read_csv(path)
        df['SOURCE_SAMPLE'] = n
        carrier_frames.append(df)
        print(f"  Sample {n}{part}: {len(df):,} rows")

df_carrier_raw = pd.concat(carrier_frames, ignore_index=True)
df_carrier = optimize_carrier(df_carrier_raw)
del df_carrier_raw

print(f"\n  Total: {len(df_carrier):,} rows | {df_carrier.memory_usage(deep=True).sum()/1024**2:.1f} MB")
print(f"  Unique beneficiaries: {df_carrier['DESYNPUF_ID'].nunique():,}")
print(f"  Columns retained: {list(df_carrier.columns)}")

if 'CLM_FROM_DT' in df_carrier.columns:
    df_carrier['CARRIER_YEAR'] = df_carrier['CLM_FROM_DT'] // 10000
    print(f"\nCarrier claims by year:")
    print(df_carrier['CARRIER_YEAR'].value_counts().sort_index().to_string())
    df_carrier.drop(columns=['CARRIER_YEAR'], inplace=True)
# Out:
# Loading Carrier Claims (A+B parts per sample)...
#   Sample 1A: 201,321 rows
#   Sample 1B: 205,056 rows
#   Sample 2A: 206,098 rows
#   Sample 2B: 206,194 rows
#   Sample 3A: 201,392 rows
#   Sample 3B: 202,932 rows
#   Sample 4A: 204,544 rows
#   Sample 4B: 205,504 rows
#   Sample 5A: 205,104 rows
#   Sample 5B: 198,982 rows
#   Total: 2,037,127 rows | 189.8 MB
#   Unique beneficiaries: 42,295
#   Columns retained: ['DESYNPUF_ID', 'CLM_ID', 'CLM_FROM_DT', 'CLM_THRU_DT', 'PRF_PHYSN_NPI_1', 'ICD9_DGNS_CD_1', 'HCPCS_CD_1', 'LINE_NCH_PMT_AMT_1', 'LINE_ALOWD_CHRG_AMT_1']
#
# Carrier claims by year:
# CARRIER_YEAR
# 2008    736550
# 2009    801203
# 2010    499374

# %% [markdown]
# ### Block 8: Load Prescription Drug Events (Samples 1–5) — NEW

# %%
print("Loading Prescription Drug Events...")
df_pde = load_claims(
    "DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_{N}.csv",
    SAMPLES, optimize_pde, "PDE"
)
print(f"  Total: {len(df_pde):,} rows | {df_pde.memory_usage(deep=True).sum()/1024**2:.1f} MB")
print(f"  Unique beneficiaries: {df_pde['DESYNPUF_ID'].nunique():,}")
print(f"  Columns: {list(df_pde.columns)}")

if 'SRVC_DT' in df_pde.columns:
    df_pde['PDE_YEAR'] = df_pde['SRVC_DT'] // 10000
    print(f"\nPDE events by year:")
    print(df_pde['PDE_YEAR'].value_counts().sort_index().to_string())
    df_pde.drop(columns=['PDE_YEAR'], inplace=True)

print(f"\nPrescription stats (days supply):")
print(df_pde['DAYS_SUPLY_NUM'].describe().to_string())

print(f"\nUnique drug products: {df_pde['PROD_SRVC_ID'].nunique():,}")
# Out:
# Loading Prescription Drug Events...
#   Sample 1: 471,028 rows
#   Sample 2: 479,019 rows
#   Sample 3: 488,069 rows
#   Sample 4: 482,497 rows
#   Sample 5: 474,217 rows
#   Total: 2,394,830 rows | 224.8 MB
#   Unique beneficiaries: 42,704
#   Columns: ['DESYNPUF_ID', 'PDE_ID', 'SRVC_DT', 'PROD_SRVC_ID', 'QTY_DSPNSD_NUM', 'DAYS_SUPLY_NUM', 'PTNT_PAY_AMT', 'TOT_RX_CST_AMT', 'SOURCE_SAMPLE']
#
# PDE events by year:
# PDE_YEAR
# 2008    859086
# 2009    935040
# 2010    600704
#
# Prescription stats (days supply):
# count    2.394830e+06
# mean     3.413715e+01
# std      2.120376e+01
# min      0.000000e+00
# 25%      3.000000e+01
# 50%      3.000000e+01
# 75%      3.000000e+01
# max      9.000000e+01
#
# Unique drug products: 314,713

# %% [markdown]
# ### Block 9: Data Linking Validation

# %%
print("DATA LINKING VALIDATION")
print("=" * 50)

all_ben_ids = set(df_ben_2008['DESYNPUF_ID']) | set(df_ben_2009['DESYNPUF_ID']) | set(df_ben_2010['DESYNPUF_ID'])
inpatient_ids = set(df_inpatient['DESYNPUF_ID'])
outpatient_ids = set(df_outpatient['DESYNPUF_ID'])
carrier_ids = set(df_carrier['DESYNPUF_ID'])
pde_ids = set(df_pde['DESYNPUF_ID'])

print(f"Total unique beneficiaries (any year): {len(all_ben_ids):,}")
print()
for label, ids in [("Inpatient", inpatient_ids), ("Outpatient", outpatient_ids),
                   ("Carrier", carrier_ids), ("PDE", pde_ids)]:
    match = ids & all_ben_ids
    pct = len(match)/len(ids)*100 if ids else 0
    print(f"{label:12s}: {len(ids):>8,} unique IDs | {len(match):>8,} matched to beneficiary ({pct:.1f}%)")

print()
print(f"Beneficiaries with inpatient AND outpatient:  {len(inpatient_ids & outpatient_ids):,}")
print(f"Beneficiaries with inpatient AND carrier:     {len(inpatient_ids & carrier_ids):,}")
print(f"Beneficiaries with inpatient AND PDE:         {len(inpatient_ids & pde_ids):,}")
print(f"Beneficiaries with ALL data types:            {len(inpatient_ids & outpatient_ids & carrier_ids & pde_ids):,}")
# Out:
# DATA LINKING VALIDATION
# ...
# Total unique beneficiaries (any year): 50,000
#
# Inpatient   :   16,181 unique IDs |   16,181 matched to beneficiary (100.0%)
# Outpatient  :   36,626 unique IDs |   36,626 matched to beneficiary (100.0%)
# Carrier     :   42,295 unique IDs |   42,295 matched to beneficiary (100.0%)
# PDE         :   42,704 unique IDs |   42,704 matched to beneficiary (100.0%)
#
# Beneficiaries with inpatient AND outpatient:  15,554
# Beneficiaries with inpatient AND carrier:     16,147
# Beneficiaries with inpatient AND PDE:         15,651
# Beneficiaries with ALL data types:            15,068

# %% [markdown]
# ### Block 10: Save All Processed Files

# %%
print("SAVING PROCESSED FILES")
print("=" * 40)

save_map = {
    "beneficiary_2008_processed": df_ben_2008,
    "beneficiary_2009_processed": df_ben_2009,
    "beneficiary_2010_processed": df_ben_2010,
    "inpatient_processed":        df_inpatient,
    "outpatient_processed":       df_outpatient,
    "carrier_processed":          df_carrier,
    "pde_processed":              df_pde,
}

for name, df in save_map.items():
    path = f"{PROCESSED}{name}.parquet"
    df.to_parquet(path, index=False)
    size_mb = os.path.getsize(path) / 1024**2
    print(f"  ✓ {name}.parquet  ({len(df):,} rows, {size_mb:.1f} MB)")

print("\nAll files saved.")
# Out:
# SAVING PROCESSED FILES
# ...
#   ✓ beneficiary_2008_processed.parquet  (50,000 rows, 1.5 MB)
#   ✓ beneficiary_2009_processed.parquet  (49,267 rows, 1.5 MB)
#   ✓ beneficiary_2010_processed.parquet  (48,511 rows, 1.4 MB)
#   ✓ inpatient_processed.parquet  (28,695 rows, 1.7 MB)
#   ✓ outpatient_processed.parquet  (340,114 rows, 7.5 MB)
#   ✓ carrier_processed.parquet  (2,037,127 rows, 40.4 MB)
#   ✓ pde_processed.parquet  (2,394,830 rows, 43.5 MB)
#
# All files saved.

# %% [markdown]
# ### Block 11: Phase A Summary

# %%
print("=" * 60)
print("PHASE A COMPLETE — DATA LOADING & EXPLORATION")
print("=" * 60)

summary = {
    "Beneficiary 2008": df_ben_2008,
    "Beneficiary 2009": df_ben_2009,
    "Beneficiary 2010": df_ben_2010,
    "Inpatient Claims": df_inpatient,
    "Outpatient Claims": df_outpatient,
    "Carrier Claims":   df_carrier,
    "PDE":              df_pde,
}

for label, df in summary.items():
    print(f"  {label:<22}: {len(df):>9,} rows | {df['DESYNPUF_ID'].nunique():>7,} unique IDs")

print()
print("NEW vs ORIGINAL pipeline:")
print("  ORIGINAL: 2 data types (Beneficiary + Inpatient), Sample 1 only")
print(f"  NEW:      7 data types, Samples {SAMPLES}")
print()
print("Next: Notebook 02 — Data Combination & Preprocessing")
# Out:
# ...
# PHASE A COMPLETE — DATA LOADING & EXPLORATION
# ...
#   Beneficiary 2008      :    50,000 rows |  50,000 unique IDs
#   Beneficiary 2009      :    49,267 rows |  49,267 unique IDs
#   Beneficiary 2010      :    48,511 rows |  48,511 unique IDs
#   Inpatient Claims      :    28,695 rows |  16,181 unique IDs
#   Outpatient Claims     :   340,114 rows |  36,626 unique IDs
#   Carrier Claims        : 2,037,127 rows |  42,295 unique IDs
#   PDE                   : 2,394,830 rows |  42,704 unique IDs
#
# NEW vs ORIGINAL pipeline:
#   ORIGINAL: 2 data types (Beneficiary + Inpatient), Sample 1 only
#   NEW:      7 data types, Samples [1, 2, 3, 4, 5]
#
# Next: Notebook 02 — Data Combination & Preprocessing
